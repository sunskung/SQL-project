# %% [markdown]
# ### **ipython-sql**
# Created by catherinedevlin on Github, this enables the use of SQL magic functions that contain % and %% , allowing you to write SQL style code right in Jupyter Notebook.
#
# ### **sqlalchemy**
# Originally authored by Michael Bayer, sqlalchemy is touted as a “SQL toolkit and object-relational-mapper” for Python. For the purposes of this tutorial, it will mainly be used to store SQL queries into a pandas dataframe.
#
# ### **psycopg2**
# The third library depends on what SQL software you choose to use. For PostgreSQL, you would use psycopg2:
#
# Different DBAPIs are documented on sqlalchemy’s website [click](https://docs.sqlalchemy.org/en/13/core/engines.html), like MySQL, Oracle, and SQLite (thanks Dave Campbell).
#
# https://medium.com/analytics-vidhya/postgresql-integration-with-jupyter-notebook-deb97579a38d

# %%
# !pip install ipython-sql --quiet
# !pip install sqlalchemy --quiet
# !pip install jovian --upgrade --quiet
# !pip install psycopg2 --quiet

# %%
import pandas as pd

# %%
# %load_ext sql

# %%
from sqlalchemy import create_engine

# %% [markdown]
# To connect ipython-sql to your database, use the following format:

# %%
# %sql postgresql://postgres:00121359sql@localhost/sunsql

# %%
engine = create_engine('postgresql://postgres:00121359sql@localhost/sunsql')

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     person
# LIMIT
#     3
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 3 rows affected.
# [(UUID('cf4055c4-bed3-4558-87f5-a3f5b42b0003'), 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', None),
#  (UUID('e357dcc0-8088-4f64-a168-b9608c6bc0fb'), 'Adriana', 'Matuschek', 'Female', 'amatuschek2@feedburner.com', datetime.date(1965, 2, 28), 'Cameroon', UUID('f262cf81-6b5f-4440-9de6-1d0410b15646')),
#  (UUID('8ead019b-f873-4688-a2d2-5fe35cbd475c'), 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', UUID('f00fd8c5-97ee-43fa-9497-b82b4038e635'))]

# %%
jovian.commit(project = 'intro-postgresql')
# Out:
# [jovian] Updating notebook "sunskung/intro-postgresql" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/sunskung/intro-postgresql
# 'https://jovian.ai/sunskung/intro-postgresql'

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     person
# WHERE
#     date_of_birth
# BETWEEN DATE
#     '2020-01-01' AND '2021-01-01'
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 420 rows affected.
# [(1, 'Anton', 'Robiou', 'arobiou0@amazon.co.jp', 'Agender', datetime.date(2020, 9, 23), 'Brazil'),
#  (4, 'Henka', 'Spare', 'hspare3@dedecms.com', 'Non-binary', datetime.date(2020, 10, 1), 'Chile'),
#  (7, 'Harcourt', 'Gorman', 'hgorman6@blogspot.com', 'Non-binary', datetime.date(2020, 10, 1), 'Australia'),
#  (8, 'Brandea', 'Ohms', None, 'Male', datetime.date(2020, 12, 25), 'Ireland'),
#  (10, 'Lukas', 'Clerke', 'lclerke9@devhub.com', 'Polygender', datetime.date(2020, 8, 4), 'Greece'),
#  (13, 'Deloris', 'Komorowski', None, 'Agender', datetime.date(2020, 10, 3), 'Indonesia'),
#  (14, 'Lu', 'Patis', None, 'Genderfluid', datetime.date(2020, 12, 7), 'Philippines'),
#  (16, 'Darcy', 'Duprey', None, 'Agender', datetime.date(2020, 12, 29), 'China'),
#  (19, 'Lucais', 'Biaggetti', 'lbiaggettii@smugmug.com', 'Non-binary', datetime.date(2020, 9, 6), 'Samoa'),
#  (26, 'Burk', 'Betteney', 'bbetteneyp@google.it', 'Bigender', datetime.date(2020, 12, 9), 'China'),
#  (27, 'Sinclare', 'Podbury', None, 'Polygender', datetime.date(2020, 10, 16), 'Sweden'),
#  (30, 'Joey', 'Croote', 'jcrootet@twitpic.com', 'Female', datetime.date(2020, 9, 10), 'Sweden'),
#  (31, 'Kurtis', 'Andreaccio', None, 'Genderqueer', datetime.date(2020, 12, 20), 'Brazil'),
#  (35, 'Puff', 'Braunle', 'pbraunley@1688.com', 'Female', datetime.date(2020, 11, 13), 'Brazil'),
#  (36, 'Antonin', 'Halson', 'ahalsonz@ed.gov', 'Agender', datetime.date(2020, 9, 16), 'China'),
#  (37, 'Teddie', 'Benes', 'tbenes10@wsj.com', 'Bigender', datetime.date(2020, 10, 8), 'South Africa'),
#  (38, 'Melanie', 'Gethouse', 'mgethouse11@clickbank.net', 'Genderqueer', datetime.date(2020, 9, 17), 'Brazil'),
#  (40, 'Bernardina', 'Langelaan', None, 'Female', datetime.date(2020, 10, 25), 'Thailand'),
#  (43, 'Pavel', 'Clinton', 'pclinton16@apache.org', 'Agender', datetime.date(2020, 12, 9), 'Indonesia'),
#  (44, 'Reena', 'Spreckley', 'rspreckley17@phpbb.com', 'Female', datetime.date(2020, 10, 26), 'Brazil'),
#  (45, 'Gasparo', 'Rosendall', 'grosendall18@gnu.org', 'Agender', datetime.date(2020, 8, 20), 'Sweden'),
#  (53, 'Stevie', 'Poundesford', 'spoundesford1g@sourceforge.net', 'Genderfluid', datetime.date(2020, 10, 28), 'Angola'),
#  (56, 'Lawry', 'Gauthorpp', 'lgauthorpp1j@ehow.com', 'Female', datetime.date(2020, 10, 28), 'China'),
#  (57, 'Simmonds', 'Smee', 'ssmee1k@hibu.com', 'Genderfluid', datetime.date(2020, 12, 1), 'Indonesia'),
#  (59, 'Arther', 'Cassimer', 'acassimer1m@upenn.edu', 'Agender', datetime.date(2020, 9, 13), 'Russia'),
#  (60, 'Devland', 'McIndoe', 'dmcindoe1n@fotki.com', 'Genderqueer', datetime.date(2020, 10, 2), 'Mexico'),
#  (61, 'Jarid', 'Jirsa', None, 'Male', datetime.date(2020, 11, 2), 'Panama'),
#  (64, 'Kriste', 'Sulman', None, 'Bigender', datetime.date(2020, 9, 3), 'Indonesia'),
#  (66, 'Barbara-anne', 'Wreight', 'bwreight1t@slideshare.net', 'Polygender', datetime.date(2020, 12, 31), 'Brazil'),
#  (71, 'Jackie', 'Tuhy', 'jtuhy1y@omniture.com', 'Polygender', datetime.date(2020, 9, 21), 'Indonesia'),
#  (74, 'Denver', 'Simounet', 'dsimounet21@constantcontact.com', 'Polygender', datetime.date(2020, 12, 5), 'Russia'),
#  (78, 'Northrop', 'Melbourne', 'nmelbourne25@clickbank.net', 'Genderfluid', datetime.date(2020, 9, 26), 'France'),
#  (81, 'Celinka', 'Thunnercliff', 'cthunnercliff28@nytimes.com', 'Genderfluid', datetime.date(2020, 9, 20), 'Sweden'),
#  (84, 'Mable', 'Ert', 'mert2b@example.com', 'Female', datetime.date(2020, 9, 12), 'Finland'),
#  (85, 'Morganne', 'McMenemy', 'mmcmenemy2c@yandex.ru', 'Genderfluid', datetime.date(2020, 12, 14), 'China'),
#  (86, 'Johnathon', 'Mynett', 'jmynett2d@forbes.com', 'Genderfluid', datetime.date(2020, 10, 5), 'Sri Lanka'),
#  (91, 'Reinhold', 'Woolforde', 'rwoolforde2i@mac.com', 'Genderqueer', datetime.date(2020, 9, 25), 'Greece'),
#  (92, 'Dag', 'McGrail', 'dmcgrail2j@t-online.de', 'Male', datetime.date(2020, 10, 4), 'China'),
#  (94, 'Alidia', 'Gallyhaock', None, 'Female', datetime.date(2020, 11, 26), 'Malaysia'),
#  (96, 'Burke', 'McGuire', None, 'Female', datetime.date(2020, 10, 31), 'Albania'),
#  (97, 'Kacy', 'McCaw', 'kmccaw2o@plala.or.jp', 'Genderfluid', datetime.date(2020, 11, 21), 'China'),
#  (98, 'Hunt', 'Archanbault', 'harchanbault2p@bloomberg.com', 'Non-binary', datetime.date(2020, 11, 7), 'China'),
#  (102, 'Myron', 'Bulstrode', 'mbulstrode2t@howstuffworks.com', 'Genderfluid', datetime.date(2020, 11, 1), 'China'),
#  (103, 'Noelyn', 'Overthrow', 'noverthrow2u@cam.ac.uk', 'Genderfluid', datetime.date(2020, 10, 4), 'Malawi'),
#  (105, 'Kellina', 'Blowfield', None, 'Polygender', datetime.date(2020, 9, 8), 'Philippines'),
#  (106, 'Cory', 'Munnery', 'cmunnery2x@bloglines.com', 'Bigender', datetime.date(2020, 10, 27), 'Russia'),
#  (108, 'Korey', 'Baldacco', 'kbaldacco2z@seattletimes.com', 'Non-binary', datetime.date(2020, 10, 29), 'Norway'),
#  (109, 'Everett', 'Ribbon', 'eribbon30@sohu.com', 'Genderfluid', datetime.date(2020, 10, 17), 'France'),
#  (113, 'Gabrila', 'Radwell', None, 'Male', datetime.date(2020, 11, 29), 'Argentina'),
#  (114, 'Breanne', 'Hiorn', None, 'Polygender', datetime.date(2020, 12, 29), 'Indonesia'),
#  (115, 'Kellie', 'Mordey', None, 'Genderfluid', datetime.date(2020, 12, 4), 'China'),
#  (117, 'Decca', 'Quinion', 'dquinion38@people.com.cn', 'Non-binary', datetime.date(2020, 9, 14), 'Russia'),
#  (123, 'Reeta', 'MacKellar', None, 'Non-binary', datetime.date(2020, 10, 5), 'Mongolia'),
#  (125, 'Grover', 'Mathelon', None, 'Agender', datetime.date(2020, 11, 22), 'France'),
#  (127, 'Maureen', 'Richin', 'mrichin3i@washingtonpost.com', 'Agender', datetime.date(2020, 12, 16), 'Indonesia'),
#  (133, 'Gabbey', "O'Nowlan", 'gonowlan3o@auda.org.au', 'Agender', datetime.date(2020, 10, 25), 'Peru'),
#  (134, 'Gabe', 'Greatrex', None, 'Genderqueer', datetime.date(2020, 9, 12), 'United States'),
#  (136, 'Torie', 'Tonbridge', 'ttonbridge3r@mysql.com', 'Genderqueer', datetime.date(2020, 8, 28), 'China'),
#  (145, 'Burr', 'Byrnes', None, 'Polygender', datetime.date(2020, 12, 25), 'Central African Republic'),
#  (147, 'Valida', 'Morriarty', 'vmorriarty42@wired.com', 'Bigender', datetime.date(2020, 11, 27), 'Argentina'),
#  (150, 'Mata', 'Eliasson', 'meliasson45@timesonline.co.uk', 'Genderqueer', datetime.date(2020, 12, 14), 'Kosovo'),
#  (152, 'Isador', 'Lewknor', 'ilewknor47@fema.gov', 'Agender', datetime.date(2020, 9, 13), 'Chile'),
#  (153, 'Lincoln', 'Papierz', 'lpapierz48@quantcast.com', 'Genderqueer', datetime.date(2020, 8, 17), 'Kyrgyzstan'),
#  (154, 'Danell', 'Merriday', 'dmerriday49@samsung.com', 'Bigender', datetime.date(2020, 9, 17), 'Philippines'),
#  (155, 'Berny', 'Beranek', 'bberanek4a@list-manage.com', 'Non-binary', datetime.date(2020, 8, 25), 'Malaysia'),
#  (159, 'Gardiner', 'Dyer', 'gdyer4e@aol.com', 'Genderfluid', datetime.date(2020, 10, 18), 'Kyrgyzstan'),
#  (161, 'Dionne', 'Shitliffe', 'dshitliffe4g@fc2.com', 'Genderqueer', datetime.date(2020, 9, 14), 'Lithuania'),
#  (163, 'Allene', 'Dunkerly', 'adunkerly4i@sphinn.com', 'Genderfluid', datetime.date(2020, 10, 8), 'Tunisia'),
#  (165, 'Jack', 'Beacom', 'jbeacom4k@nps.gov', 'Genderqueer', datetime.date(2020, 10, 6), 'Indonesia'),
#  (166, 'Kariotta', 'Dymond', None, 'Female', datetime.date(2020, 10, 14), 'France'),
#  (168, 'Faustina', 'Soot', 'fsoot4n@xrea.com', 'Bigender', datetime.date(2020, 9, 27), 'Poland'),
#  (169, 'Jo ann', 'Flageul', 'jflageul4o@usa.gov', 'Genderfluid', datetime.date(2020, 12, 26), 'Indonesia'),
#  (175, 'Cherilynn', 'Woodnutt', 'cwoodnutt4u@alexa.com', 'Agender', datetime.date(2020, 11, 23), 'Thailand'),
#  (177, 'Riley', 'Ellesworthe', None, 'Bigender', datetime.date(2020, 12, 20), 'Portugal'),
#  (180, 'Bell', 'Scadden', None, 'Female', datetime.date(2020, 10, 8), 'Tunisia'),
#  (182, 'Shaun', 'Purbrick', 'spurbrick51@ftc.gov', 'Polygender', datetime.date(2020, 9, 20), 'China'),
#  (183, 'Zola', 'Ivery', 'zivery52@naver.com', 'Non-binary', datetime.date(2020, 12, 1), 'Ukraine'),
#  (186, 'Joletta', 'Forrest', None, 'Polygender', datetime.date(2020, 10, 31), 'Afghanistan'),
#  (188, 'Arnold', 'Alves', 'aalves57@msu.edu', 'Genderqueer', datetime.date(2020, 10, 12), 'Luxembourg'),
#  (189, 'Dani', 'Dooley', None, 'Polygender', datetime.date(2020, 12, 15), 'Colombia'),
#  (190, 'Enrika', 'Chesher', 'echesher59@cafepress.com', 'Agender', datetime.date(2020, 9, 5), 'Tanzania'),
#  (192, 'Terencio', 'Silberschatz', 'tsilberschatz5b@wisc.edu', 'Bigender', datetime.date(2020, 10, 6), 'Peru'),
#  (193, 'Keefe', 'Tatters', 'ktatters5c@sohu.com', 'Genderfluid', datetime.date(2020, 10, 8), 'Colombia'),
#  (195, 'Ginger', 'Lavery', None, 'Female', datetime.date(2020, 10, 4), 'France'),
#  (196, 'Randy', 'Lagne', 'rlagne5f@techcrunch.com', 'Genderqueer', datetime.date(2020, 12, 16), 'Serbia'),
#  (197, 'Irv', 'Coombe', 'icoombe5g@hibu.com', 'Polygender', datetime.date(2020, 11, 2), 'China'),
#  (200, 'Kaylee', 'Canario', 'kcanario5j@rambler.ru', 'Female', datetime.date(2020, 9, 23), 'Portugal'),
#  (204, 'Tyler', 'Lorrie', 'tlorrie5n@hp.com', 'Genderfluid', datetime.date(2020, 9, 10), 'Peru'),
#  (208, 'Ediva', 'Butting', 'ebutting5r@bing.com', 'Female', datetime.date(2020, 10, 11), 'China'),
#  (209, 'Ameline', 'Pinckard', 'apinckard5s@oakley.com', 'Male', datetime.date(2020, 12, 4), 'Portugal'),
#  (210, 'Elita', 'Twigg', 'etwigg5t@1688.com', 'Male', datetime.date(2020, 10, 21), 'France'),
#  (214, 'Dennet', 'Durnford', 'ddurnford5x@comsenz.com', 'Agender', datetime.date(2020, 11, 12), 'Indonesia'),
#  (215, 'Alonzo', 'Fruchon', 'afruchon5y@wired.com', 'Genderqueer', datetime.date(2020, 11, 1), 'Guatemala'),
#  (216, 'Hazel', 'Boyer', 'hboyer5z@wsj.com', 'Genderqueer', datetime.date(2020, 12, 14), 'Jordan'),
#  (220, 'Gussy', 'Ruperto', 'gruperto63@dailymotion.com', 'Non-binary', datetime.date(2020, 12, 18), 'Nigeria'),
#  (221, 'Gunther', 'Rushforth', 'grushforth64@t.co', 'Female', datetime.date(2020, 11, 28), 'Mali'),
#  (224, 'Alfy', 'Dolbey', None, 'Agender', datetime.date(2020, 9, 2), 'China'),
#  (225, 'Mike', 'Rummin', 'mrummin68@ycombinator.com', 'Non-binary', datetime.date(2020, 12, 27), 'Philippines'),
#  (227, 'Horace', 'Jannequin', 'hjannequin6a@whitehouse.gov', 'Bigender', datetime.date(2020, 10, 1), 'China'),
#  (229, 'Chen', 'Dankov', 'cdankov6c@ed.gov', 'Genderqueer', datetime.date(2020, 10, 16), 'China'),
#  (230, 'Dannye', 'Bosomworth', 'dbosomworth6d@newyorker.com', 'Bigender', datetime.date(2020, 8, 7), 'Poland'),
#  (232, 'Thia', 'Barsam', 'tbarsam6f@springer.com', 'Female', datetime.date(2020, 8, 19), 'Mexico'),
#  (234, 'Beulah', 'Bladesmith', 'bbladesmith6h@dion.ne.jp', 'Male', datetime.date(2020, 8, 27), 'Brazil'),
#  (235, 'Neal', 'Le Teve', 'nleteve6i@tuttocitta.it', 'Non-binary', datetime.date(2020, 8, 4), 'Sweden'),
#  (236, 'Ernst', 'Ive', 'eive6j@list-manage.com', 'Male', datetime.date(2020, 8, 21), 'Czech Republic'),
#  (238, 'Wit', 'Maso', None, 'Female', datetime.date(2020, 11, 22), 'Palestinian Territory'),
#  (246, 'Salmon', 'Delahunt', 'sdelahunt6t@techcrunch.com', 'Female', datetime.date(2020, 8, 14), 'Russia'),
#  (251, 'Becki', 'Ridder', None, 'Non-binary', datetime.date(2020, 12, 24), 'Ukraine'),
#  (253, 'Erroll', 'Bynert', 'ebynert70@marriott.com', 'Female', datetime.date(2020, 9, 20), 'Philippines'),
#  (254, 'Bendick', 'Andrag', 'bandrag71@photobucket.com', 'Bigender', datetime.date(2020, 11, 9), 'Nigeria'),
#  (256, 'Amelia', 'Davydoch', 'adavydoch73@dailymotion.com', 'Non-binary', datetime.date(2020, 11, 18), 'Sweden'),
#  (257, 'Skipper', 'Tower', 'stower74@parallels.com', 'Genderqueer', datetime.date(2020, 10, 1), 'United Kingdom'),
#  (522, 'Arv', 'Lydiatt', None, 'Agender', datetime.date(2020, 12, 6), 'Finland'),
#  (260, 'Kettie', 'Jamary', 'kjamary77@house.gov', 'Female', datetime.date(2020, 9, 19), 'Russia'),
#  (261, 'Janessa', 'Stammer', 'jstammer78@nba.com', 'Non-binary', datetime.date(2021, 1, 1), 'China'),
#  (262, 'Raff', 'Tourner', None, 'Genderqueer', datetime.date(2020, 9, 5), 'China'),
#  (264, 'Mendie', 'Jordine', None, 'Male', datetime.date(2020, 10, 11), 'Philippines'),
#  (270, 'Geri', 'Garfit', None, 'Genderqueer', datetime.date(2020, 9, 21), 'Poland'),
#  (271, 'Phil', 'Nolot', 'pnolot7i@tripadvisor.com', 'Genderqueer', datetime.date(2020, 8, 8), 'Brazil'),
#  (274, 'Denis', 'Haddacks', 'dhaddacks7l@whitehouse.gov', 'Bigender', datetime.date(2020, 8, 24), 'Panama'),
#  (276, 'Travers', 'Pryn', None, 'Male', datetime.date(2020, 8, 10), 'Poland'),
#  (277, 'Ario', 'Rothery', 'arothery7o@homestead.com', 'Polygender', datetime.date(2020, 12, 11), 'Zimbabwe'),
#  (282, 'Wat', 'Armin', 'warmin7t@dion.ne.jp', 'Male', datetime.date(2020, 8, 3), 'United States'),
#  (285, 'Garwin', 'Gradon', 'ggradon7w@cbc.ca', 'Male', datetime.date(2020, 12, 26), 'China'),
#  (291, 'Lita', 'Sokale', None, 'Female', datetime.date(2020, 10, 27), 'Moldova'),
#  (293, 'Lorrayne', 'Maggorini', 'lmaggorini84@microsoft.com', 'Bigender', datetime.date(2020, 9, 22), 'Sweden'),
#  (294, 'Caitrin', 'Balls', 'cballs85@bravesites.com', 'Bigender', datetime.date(2020, 10, 29), 'Ghana'),
#  (295, 'Carolyne', 'Dowling', 'cdowling86@unicef.org', 'Female', datetime.date(2020, 11, 15), 'Japan'),
#  (298, 'Rhys', 'Surr', None, 'Female', datetime.date(2020, 9, 20), 'Japan'),
#  (299, 'Drew', 'Athelstan', None, 'Non-binary', datetime.date(2020, 10, 25), 'Portugal'),
#  (303, 'Virginie', 'Barbrick', 'vbarbrick8e@nature.com', 'Agender', datetime.date(2020, 9, 2), 'Japan'),
#  (306, 'Olivette', 'Camillo', 'ocamillo8h@stanford.edu', 'Male', datetime.date(2020, 8, 24), 'Poland'),
#  (309, 'Templeton', 'Glauber', None, 'Female', datetime.date(2020, 10, 26), 'Ukraine'),
#  (312, 'Dore', 'Dugall', 'ddugall8n@rakuten.co.jp', 'Genderqueer', datetime.date(2020, 12, 7), 'Indonesia'),
#  (315, 'Zonda', 'Kemer', 'zkemer8q@goo.gl', 'Genderqueer', datetime.date(2020, 10, 3), 'Sweden'),
#  (319, 'Vivianne', 'Landsborough', None, 'Non-binary', datetime.date(2020, 10, 5), 'South Africa'),
#  (320, 'Doris', 'Bedome', 'dbedome8v@google.it', 'Non-binary', datetime.date(2020, 9, 9), 'Armenia'),
#  (323, 'Christie', 'Mattioli', 'cmattioli8y@archive.org', 'Genderfluid', datetime.date(2020, 12, 8), 'Canada'),
#  (326, 'Tremayne', 'Ramshay', 'tramshay91@skyrock.com', 'Male', datetime.date(2020, 10, 23), 'Portugal'),
#  (327, 'Cheryl', 'Borleace', 'cborleace92@howstuffworks.com', 'Male', datetime.date(2020, 8, 7), 'Czech Republic'),
#  (328, 'Giorgi', 'Yepiskopov', None, 'Genderqueer', datetime.date(2020, 12, 5), 'China'),
#  (332, 'Nicoli', 'Hares', None, 'Genderqueer', datetime.date(2020, 12, 9), 'Ukraine'),
#  (334, 'Nathalie', 'Fannin', 'nfannin99@fema.gov', 'Genderqueer', datetime.date(2020, 11, 15), 'Poland'),
#  (335, 'Andrej', 'Hansod', 'ahansod9a@bbb.org', 'Male', datetime.date(2020, 9, 25), 'Greece'),
#  (341, 'Enid', 'De Malchar', 'edemalchar9g@indiatimes.com', 'Genderfluid', datetime.date(2020, 12, 1), 'Poland'),
#  (344, 'Patty', 'Laverack', 'plaverack9j@stanford.edu', 'Genderqueer', datetime.date(2020, 8, 20), 'Brazil'),
#  (345, 'Scarlett', 'Yoselevitch', 'syoselevitch9k@shareasale.com', 'Bigender', datetime.date(2020, 8, 11), 'China'),
#  (346, 'Rosa', 'Brenton', 'rbrenton9l@ucoz.ru', 'Genderfluid', datetime.date(2020, 12, 5), 'Brazil'),
#  (361, 'Malina', 'Domleo', 'mdomleoa0@de.vu', 'Male', datetime.date(2020, 9, 7), 'China'),
#  (363, 'Cece', 'Maciocia', 'cmaciociaa2@theatlantic.com', 'Non-binary', datetime.date(2020, 11, 27), 'Colombia'),
#  (364, 'Bertrand', 'Renehan', None, 'Agender', datetime.date(2020, 11, 9), 'China'),
#  (366, 'Rafferty', 'Oaten', 'roatena5@toplist.cz', 'Female', datetime.date(2020, 11, 19), 'China'),
#  (368, 'Storm', 'Buckwell', 'sbuckwella7@webnode.com', 'Male', datetime.date(2020, 10, 24), 'Kuwait'),
#  (375, 'Marilyn', 'Hallam', 'mhallamae@seattletimes.com', 'Bigender', datetime.date(2020, 8, 14), 'Kenya'),
#  (376, 'Beck', 'Spragge', 'bspraggeaf@slate.com', 'Male', datetime.date(2020, 9, 28), 'Russia'),
#  (377, 'Tomkin', 'Halmkin', 'thalmkinag@wordpress.org', 'Genderfluid', datetime.date(2020, 12, 31), 'Czech Republic'),
#  (378, 'Elsworth', 'Merwood', None, 'Genderfluid', datetime.date(2020, 12, 21), 'China'),
#  (382, 'Ash', 'Gabbott', 'agabbottal@livejournal.com', 'Polygender', datetime.date(2020, 10, 9), 'Uruguay'),
#  (386, 'Hoebart', 'Liddicoat', 'hliddicoatap@google.com.au', 'Non-binary', datetime.date(2020, 11, 27), 'Panama'),
#  (387, 'Annie', 'De Robertis', 'aderobertisaq@macromedia.com', 'Genderqueer', datetime.date(2020, 10, 31), 'China'),
#  (390, 'Violet', 'Nicholas', 'vnicholasat@usa.gov', 'Non-binary', datetime.date(2020, 9, 6), 'Indonesia'),
#  (393, 'Bevon', 'MacMenemy', None, 'Agender', datetime.date(2020, 10, 6), 'Mauritius'),
#  (394, 'Hewitt', 'Bigland', 'hbiglandax@sbwire.com', 'Female', datetime.date(2020, 11, 24), 'Indonesia'),
#  (395, 'Nealy', 'Everest', None, 'Agender', datetime.date(2020, 8, 29), 'Argentina'),
#  (396, 'Rosella', 'Adamsson', 'radamssonaz@examiner.com', 'Female', datetime.date(2020, 9, 7), 'China'),
#  (397, 'Laetitia', 'Landy', 'llandyb0@reverbnation.com', 'Bigender', datetime.date(2020, 11, 6), 'Russia'),
#  (400, 'Margaretha', 'Pray', 'mprayb3@163.com', 'Genderfluid', datetime.date(2020, 9, 7), 'Indonesia'),
#  (401, 'Elizabeth', 'Limrick', 'elimrickb4@mit.edu', 'Male', datetime.date(2020, 9, 28), 'Ukraine'),
#  (402, 'Shelby', 'Couronne', 'scouronneb5@plala.or.jp', 'Genderfluid', datetime.date(2020, 9, 25), 'China'),
#  (403, 'Stan', 'Seivwright', 'sseivwrightb6@epa.gov', 'Bigender', datetime.date(2020, 11, 3), 'China'),
#  (405, 'Haven', 'Cullinane', 'hcullinaneb8@tumblr.com', 'Agender', datetime.date(2020, 9, 7), 'China'),
#  (407, 'Percy', 'MacAskie', 'pmacaskieba@rakuten.co.jp', 'Bigender', datetime.date(2020, 8, 31), 'Japan'),
#  (413, 'Isiahi', 'Tatford', 'itatfordbg@earthlink.net', 'Non-binary', datetime.date(2020, 10, 8), 'Chile'),
#  (415, 'Algernon', 'Schechter', None, 'Male', datetime.date(2020, 11, 22), 'Malta'),
#  (416, 'Charlotta', 'Harsant', None, 'Male', datetime.date(2020, 10, 17), 'China'),
#  (418, 'Alasdair', 'Tiddeman', None, 'Female', datetime.date(2020, 12, 20), 'China'),
#  (419, 'Elita', 'Lansberry', 'elansberrybm@dell.com', 'Agender', datetime.date(2020, 10, 26), 'Brazil'),
#  (422, 'Aretha', 'Steele', 'asteelebp@illinois.edu', 'Female', datetime.date(2020, 12, 5), 'South Korea'),
#  (427, 'Adore', 'Twomey', None, 'Bigender', datetime.date(2020, 10, 24), 'China'),
#  (429, 'Wake', 'Rodnight', None, 'Bigender', datetime.date(2020, 8, 28), 'Indonesia'),
#  (432, 'Byran', 'Kivell', None, 'Bigender', datetime.date(2020, 10, 4), 'Indonesia'),
#  (440, 'Linn', 'Harker', 'lharkerc7@columbia.edu', 'Male', datetime.date(2020, 9, 23), 'Brazil'),
#  (441, 'Lowrance', 'Gummory', 'lgummoryc8@google.de', 'Genderfluid', datetime.date(2020, 10, 26), 'China'),
#  (445, 'Bryna', 'Prophet', 'bprophetcc@npr.org', 'Genderqueer', datetime.date(2020, 11, 7), 'Indonesia'),
#  (450, 'Gabi', 'Pass', 'gpassch@yale.edu', 'Female', datetime.date(2020, 9, 18), 'Thailand'),
#  (451, 'Krystyna', 'Tomankiewicz', 'ktomankiewiczci@umn.edu', 'Genderqueer', datetime.date(2020, 8, 28), 'China'),
#  (452, 'Kalli', 'Amerighi', 'kamerighicj@usnews.com', 'Polygender', datetime.date(2020, 8, 31), 'Russia'),
#  (458, 'Marcelo', 'Matschuk', 'mmatschukcp@elegantthemes.com', 'Bigender', datetime.date(2020, 11, 21), 'Portugal'),
#  (460, 'Enrika', 'Bernet', 'ebernetcr@free.fr', 'Female', datetime.date(2020, 12, 17), 'Cyprus'),
#  (462, 'Kamila', 'McTrustey', None, 'Polygender', datetime.date(2020, 8, 10), 'Uganda'),
#  (463, 'Sioux', 'Westoll', 'swestollcu@si.edu', 'Genderqueer', datetime.date(2020, 12, 2), 'China'),
#  (468, 'Ebeneser', 'Alebrooke', 'ealebrookecz@slate.com', 'Polygender', datetime.date(2020, 9, 18), 'China'),
#  (469, 'Cherin', 'Danter', None, 'Genderqueer', datetime.date(2020, 9, 11), 'Sweden'),
#  (470, 'Philly', 'Dohmann', 'pdohmannd1@sitemeter.com', 'Genderfluid', datetime.date(2020, 10, 12), 'Indonesia'),
#  (472, 'Fleur', 'Chittenden', 'fchittendend3@mit.edu', 'Male', datetime.date(2020, 10, 18), 'China'),
#  (473, 'Aila', 'Renfree', 'arenfreed4@walmart.com', 'Bigender', datetime.date(2020, 8, 28), 'Brazil'),
#  (474, 'Normie', 'Eckart', None, 'Female', datetime.date(2020, 11, 1), 'Japan'),
#  (477, 'Renato', 'Marner', 'rmarnerd8@dedecms.com', 'Agender', datetime.date(2020, 9, 20), 'Ecuador'),
#  (478, 'Sonny', 'Bucknall', 'sbucknalld9@gov.uk', 'Non-binary', datetime.date(2020, 11, 27), 'Brazil'),
#  (480, 'Charmine', 'Perrat', 'cperratdb@exblog.jp', 'Genderfluid', datetime.date(2020, 9, 3), 'Croatia'),
#  (481, 'Agna', 'Burton', 'aburtondc@tumblr.com', 'Polygender', datetime.date(2020, 11, 10), 'Pakistan'),
#  (484, 'Nadeen', 'Eddins', 'neddinsdf@nsw.gov.au', 'Bigender', datetime.date(2020, 9, 10), 'Finland'),
#  (486, 'Gregoire', 'Eamer', None, 'Male', datetime.date(2020, 9, 3), 'Thailand'),
#  (489, 'Yance', 'Oakley', None, 'Non-binary', datetime.date(2020, 12, 8), 'China'),
#  (491, 'Justinian', 'Stockport', 'jstockportdm@irs.gov', 'Genderqueer', datetime.date(2020, 9, 9), 'South Africa'),
#  (492, 'Faber', 'Kleinstein', None, 'Female', datetime.date(2020, 11, 11), 'United States'),
#  (495, 'Teirtza', 'Milkins', 'tmilkinsdq@w3.org', 'Genderfluid', datetime.date(2020, 8, 19), 'China'),
#  (496, 'Sharl', 'Baskeyfied', None, 'Polygender', datetime.date(2020, 10, 9), 'Portugal'),
#  (500, 'Pedro', 'Attlee', 'pattleedv@weibo.com', 'Non-binary', datetime.date(2020, 10, 18), 'France'),
#  (503, 'Alphonse', 'Juzek', None, 'Non-binary', datetime.date(2020, 8, 26), 'Bangladesh'),
#  (504, 'Malchy', 'Smissen', 'msmissendz@hexun.com', 'Agender', datetime.date(2020, 11, 3), 'United States'),
#  (509, 'Matty', 'Rachuig', 'mrachuige4@edublogs.org', 'Agender', datetime.date(2020, 11, 22), 'Thailand'),
#  (510, 'Constantina', 'Beautyman', None, 'Agender', datetime.date(2020, 9, 22), 'Kiribati'),
#  (514, 'Moritz', 'Steckings', 'msteckingse9@un.org', 'Male', datetime.date(2020, 10, 18), 'Cambodia'),
#  (517, 'Vi', 'Labrenz', 'vlabrenzec@devhub.com', 'Male', datetime.date(2020, 9, 4), 'New Zealand'),
#  (520, 'Ibrahim', 'Roughan', 'iroughanef@diigo.com', 'Male', datetime.date(2020, 11, 13), 'Indonesia'),
#  (523, 'Klarrisa', 'Summerlie', None, 'Genderfluid', datetime.date(2020, 12, 10), 'Indonesia'),
#  (524, 'Laverna', 'Dunford', 'ldunfordej@google.com.au', 'Polygender', datetime.date(2020, 12, 6), 'China'),
#  (527, 'Jodi', 'Beynon', 'jbeynonem@theglobeandmail.com', 'Agender', datetime.date(2020, 9, 29), 'Peru'),
#  (528, 'Athena', 'Merritt', 'amerritten@statcounter.com', 'Agender', datetime.date(2020, 11, 18), 'Indonesia'),
#  (530, 'Olympe', 'Dutton', 'oduttonep@ftc.gov', 'Non-binary', datetime.date(2020, 9, 1), 'Russia'),
#  (531, 'Nicolis', 'McIlveen', 'nmcilveeneq@1und1.de', 'Male', datetime.date(2020, 8, 24), 'Russia'),
#  (533, 'Bess', 'Navein', 'bnaveines@epa.gov', 'Male', datetime.date(2020, 8, 22), 'Mexico'),
#  (534, 'Gearalt', 'Carvill', None, 'Male', datetime.date(2020, 8, 13), 'Canada'),
#  (539, 'Shepperd', 'Crowden', 'scrowdeney@feedburner.com', 'Non-binary', datetime.date(2020, 12, 5), 'China'),
#  (540, 'Merralee', 'Brigstock', 'mbrigstockez@canalblog.com', 'Polygender', datetime.date(2020, 10, 15), 'Chad'),
#  (542, 'Faun', 'Crowdy', 'fcrowdyf1@vk.com', 'Bigender', datetime.date(2020, 8, 19), 'China'),
#  (545, 'Auberta', 'Barwell', 'abarwellf4@ucsd.edu', 'Non-binary', datetime.date(2020, 9, 3), 'France'),
#  (549, 'Austina', 'Garnar', None, 'Bigender', datetime.date(2020, 11, 4), 'Botswana'),
#  (550, 'Elenore', 'Bricknell', 'ebricknellf9@chicagotribune.com', 'Genderfluid', datetime.date(2020, 11, 14), 'Philippines'),
#  (552, 'Tyrus', 'Postles', 'tpostlesfb@oracle.com', 'Agender', datetime.date(2020, 10, 5), 'China'),
#  (553, 'Kit', 'Marzelli', None, 'Agender', datetime.date(2020, 9, 13), 'Mexico'),
#  (554, 'Kim', 'Vinick', 'kvinickfd@pinterest.com', 'Bigender', datetime.date(2020, 9, 7), 'Thailand'),
#  (555, 'Bartram', 'Rosini', 'brosinife@abc.net.au', 'Bigender', datetime.date(2020, 8, 5), 'Indonesia'),
#  (556, 'Yevette', 'Murley', 'ymurleyff@ca.gov', 'Polygender', datetime.date(2020, 12, 19), 'Mauritius'),
#  (558, 'Sigvard', 'Asbery', 'sasberyfh@go.com', 'Genderfluid', datetime.date(2020, 8, 24), 'Dominican Republic'),
#  (559, 'Kaia', 'Romei', 'kromeifi@independent.co.uk', 'Non-binary', datetime.date(2020, 12, 6), 'Peru'),
#  (566, 'Briny', 'McNamara', 'bmcnamarafp@plala.or.jp', 'Non-binary', datetime.date(2020, 9, 1), 'Uganda'),
#  (571, 'Doralynne', 'Pont', 'dpontfu@baidu.com', 'Genderqueer', datetime.date(2020, 9, 1), 'Uganda'),
#  (573, 'Rebe', 'MacGilmartin', 'rmacgilmartinfw@fc2.com', 'Agender', datetime.date(2020, 8, 6), 'Indonesia'),
#  (575, 'Milton', 'Russe', 'mrussefy@unc.edu', 'Non-binary', datetime.date(2020, 8, 29), 'Russia'),
#  (578, 'Blaire', 'Simpkin', None, 'Genderfluid', datetime.date(2020, 9, 4), 'Portugal'),
#  (583, 'Mead', 'Soigne', 'msoigneg6@pbs.org', 'Male', datetime.date(2020, 11, 1), 'Brazil'),
#  (584, 'Sibyl', 'Phipp', 'sphippg7@cyberchimps.com', 'Polygender', datetime.date(2020, 10, 8), 'China'),
#  (586, 'Stillmann', 'Yarnley', None, 'Female', datetime.date(2020, 11, 23), 'Nigeria'),
#  (587, 'Gerome', 'Brosi', None, 'Male', datetime.date(2020, 9, 17), 'Mexico'),
#  (588, 'Courtenay', 'Message', None, 'Agender', datetime.date(2020, 10, 12), 'Sweden'),
#  (593, 'Emiline', 'Simmonds', 'esimmondsgg@ca.gov', 'Non-binary', datetime.date(2020, 9, 17), 'Thailand'),
#  (596, 'Birch', 'Quodling', 'bquodlinggj@hao123.com', 'Female', datetime.date(2020, 9, 1), 'Brazil'),
#  (601, 'Yorgos', 'Pellingar', None, 'Male', datetime.date(2020, 8, 17), 'Poland'),
#  (602, 'Dennis', 'Round', 'droundgp@washingtonpost.com', 'Female', datetime.date(2020, 9, 18), 'Philippines'),
#  (603, 'Celisse', 'Vlasov', 'cvlasovgq@nature.com', 'Bigender', datetime.date(2020, 8, 6), 'Peru'),
#  (606, 'Ward', 'Hairesnape', 'whairesnapegt@disqus.com', 'Polygender', datetime.date(2020, 10, 26), 'China'),
#  (607, 'Jess', 'Edes', 'jedesgu@toplist.cz', 'Female', datetime.date(2020, 9, 24), 'Panama'),
#  (698, 'Audy', 'Long', None, 'Male', datetime.date(2020, 9, 16), 'Indonesia'),
#  (611, 'Muhammad', 'Wilshaw', 'mwilshawgy@arizona.edu', 'Female', datetime.date(2020, 9, 27), 'Portugal'),
#  (620, 'Ada', 'Whitnall', 'awhitnallh7@tiny.cc', 'Polygender', datetime.date(2020, 12, 27), 'Latvia'),
#  (621, 'Keelby', 'Bellwood', 'kbellwoodh8@epa.gov', 'Genderfluid', datetime.date(2020, 8, 22), 'China'),
#  (624, 'Bo', 'Baal', None, 'Female', datetime.date(2020, 9, 11), 'Guinea'),
#  (625, 'Suzann', 'Lenton', 'slentonhc@lycos.com', 'Male', datetime.date(2020, 11, 12), 'Indonesia'),
#  (629, 'Regan', 'Lansdown', 'rlansdownhg@prnewswire.com', 'Non-binary', datetime.date(2020, 10, 16), 'Sweden'),
#  (630, 'Ossie', 'Moretto', 'omorettohh@si.edu', 'Non-binary', datetime.date(2020, 12, 27), 'Belarus'),
#  (631, 'Anne', 'Devers', None, 'Bigender', datetime.date(2020, 10, 16), 'China'),
#  (632, 'Karon', 'Charte', 'kchartehj@auda.org.au', 'Genderfluid', datetime.date(2020, 9, 28), 'Armenia'),
#  (635, 'Rex', 'Alpes', 'ralpeshm@over-blog.com', 'Female', datetime.date(2020, 10, 22), 'Argentina'),
#  (640, 'Osmond', 'Schafer', 'oschaferhr@zdnet.com', 'Genderfluid', datetime.date(2020, 11, 18), 'Russia'),
#  (641, 'Reg', 'Canby', 'rcanbyhs@nymag.com', 'Polygender', datetime.date(2020, 10, 17), 'Peru'),
#  (644, 'Linell', 'Tunnock', 'ltunnockhv@chicagotribune.com', 'Female', datetime.date(2020, 10, 12), 'Netherlands'),
#  (645, 'Edwin', 'Biggadike', None, 'Polygender', datetime.date(2020, 9, 18), 'Greece'),
#  (648, 'Frederick', 'Crim', 'fcrimhz@parallels.com', 'Female', datetime.date(2020, 11, 29), 'China'),
#  (649, 'Hogan', 'Torresi', 'htorresii0@oracle.com', 'Agender', datetime.date(2020, 8, 28), 'China'),
#  (651, 'Derby', 'McCuthais', None, 'Genderfluid', datetime.date(2020, 11, 9), 'Ecuador'),
#  (653, 'See', 'Huffer', 'shufferi4@dropbox.com', 'Genderqueer', datetime.date(2020, 8, 22), 'Kazakhstan'),
#  (654, 'Jacquie', 'Ramard', 'jramardi5@yale.edu', 'Agender', datetime.date(2020, 8, 11), 'Sri Lanka'),
#  (656, 'Lacey', 'Dearle', 'ldearlei7@washington.edu', 'Genderqueer', datetime.date(2020, 12, 12), 'Portugal'),
#  (659, 'Tessa', 'Sloley', 'tsloleyia@marketwatch.com', 'Bigender', datetime.date(2020, 10, 31), 'Pakistan'),
#  (660, 'Vi', 'Dumingos', 'vdumingosib@tiny.cc', 'Genderqueer', datetime.date(2020, 8, 19), 'Greece'),
#  (661, 'Iosep', 'Lillegard', 'ilillegardic@addthis.com', 'Polygender', datetime.date(2020, 11, 9), 'Dominican Republic'),
#  (665, 'Daria', 'Wastling', None, 'Non-binary', datetime.date(2020, 11, 20), 'Canada'),
#  (666, 'Baxy', 'Murrell', 'bmurrellih@paginegialle.it', 'Genderfluid', datetime.date(2020, 10, 9), 'Armenia'),
#  (668, 'Mayor', 'Creebo', 'mcreeboij@oracle.com', 'Non-binary', datetime.date(2020, 9, 11), 'Venezuela'),
#  (669, 'Missy', 'Townley', 'mtownleyik@symantec.com', 'Polygender', datetime.date(2020, 10, 14), 'China'),
#  (670, 'Diarmid', 'Varker', None, 'Female', datetime.date(2020, 8, 24), 'Greece'),
#  (671, 'Delainey', 'Leigh', 'dleighim@globo.com', 'Genderqueer', datetime.date(2020, 11, 13), 'Poland'),
#  (673, 'Stacy', 'LAbbet', 'slabbetio@alibaba.com', 'Genderqueer', datetime.date(2020, 9, 30), 'Iran'),
#  (677, 'Rosabella', 'Aleshintsev', 'raleshintsevis@printfriendly.com', 'Genderfluid', datetime.date(2020, 9, 20), 'Brazil'),
#  (678, 'Casar', 'Helsby', None, 'Male', datetime.date(2020, 9, 9), 'Zimbabwe'),
#  (679, 'Chane', 'Boobyer', 'cboobyeriu@va.gov', 'Bigender', datetime.date(2020, 9, 15), 'China'),
#  (680, 'Ward', 'Spraggon', 'wspraggoniv@guardian.co.uk', 'Genderqueer', datetime.date(2020, 12, 4), 'China'),
#  (684, 'Otes', 'Elcott', None, 'Genderfluid', datetime.date(2020, 12, 2), 'Mongolia'),
#  (686, 'Jere', 'Niven', 'jnivenj1@nymag.com', 'Bigender', datetime.date(2020, 10, 11), 'Nicaragua'),
#  (687, 'Hilliard', 'Farris', 'hfarrisj2@purevolume.com', 'Genderqueer', datetime.date(2020, 8, 11), 'Indonesia'),
#  (690, 'Aline', 'Statham', None, 'Genderfluid', datetime.date(2020, 8, 12), 'Estonia'),
#  (691, 'Marrilee', 'Elies', None, 'Male', datetime.date(2020, 12, 13), 'Indonesia'),
#  (692, 'Ezekiel', 'Borrell', None, 'Polygender', datetime.date(2020, 8, 15), 'China'),
#  (694, 'Jyoti', 'Lorand', 'jlorandj9@blogs.com', 'Non-binary', datetime.date(2020, 12, 23), 'Poland'),
#  (697, 'Phylis', 'Dove', 'pdovejc@lycos.com', 'Female', datetime.date(2020, 9, 5), 'Indonesia'),
#  (700, 'Rubie', 'Morcombe', 'rmorcombejf@about.com', 'Agender', datetime.date(2020, 10, 13), 'China'),
#  (703, 'Shawn', 'Buck', 'sbuckji@psu.edu', 'Non-binary', datetime.date(2020, 8, 6), 'China'),
#  (704, 'Cassandre', 'Alpes', None, 'Non-binary', datetime.date(2020, 11, 20), 'United States'),
#  (705, 'Gayla', 'Sawter', 'gsawterjk@theglobeandmail.com', 'Genderqueer', datetime.date(2020, 9, 6), 'Uganda'),
#  (720, 'Con', 'Sextone', 'csextonejz@psu.edu', 'Polygender', datetime.date(2020, 9, 10), 'Serbia'),
#  (721, 'Dar', 'Botger', 'dbotgerk0@vistaprint.com', 'Female', datetime.date(2020, 11, 23), 'Honduras'),
#  (724, 'Early', 'Nendick', 'enendickk3@mtv.com', 'Female', datetime.date(2020, 9, 6), 'Portugal'),
#  (727, 'Tony', 'Wabe', 'twabek6@xrea.com', 'Genderfluid', datetime.date(2020, 12, 14), 'Colombia'),
#  (728, 'Mandie', 'Simonou', 'msimonouk7@moonfruit.com', 'Polygender', datetime.date(2020, 10, 29), 'Portugal'),
#  (733, 'Edgardo', 'Collip', 'ecollipkc@dyndns.org', 'Genderfluid', datetime.date(2020, 12, 4), 'Thailand'),
#  (734, 'Lelah', 'Setford', 'lsetfordkd@tinyurl.com', 'Female', datetime.date(2020, 12, 25), 'Indonesia'),
#  (738, 'Bill', 'Karleman', None, 'Female', datetime.date(2020, 12, 1), 'Jamaica'),
#  (739, 'Addie', 'MacGovern', None, 'Agender', datetime.date(2020, 12, 1), 'Indonesia'),
#  (742, 'Rosalyn', 'Elstone', 'relstonekl@wikispaces.com', 'Genderfluid', datetime.date(2020, 8, 27), 'Philippines'),
#  (743, 'Etienne', 'Billany', None, 'Genderqueer', datetime.date(2020, 10, 24), 'Madagascar'),
#  (745, 'Lyon', 'Kingscott', None, 'Genderfluid', datetime.date(2020, 10, 30), 'Japan'),
#  (746, 'August', 'Dreakin', 'adreakinkp@slashdot.org', 'Bigender', datetime.date(2020, 10, 28), 'France'),
#  (751, 'Kain', 'Pavett', None, 'Genderqueer', datetime.date(2020, 12, 29), 'Indonesia'),
#  (752, 'Geralda', 'Passy', 'gpassykv@usatoday.com', 'Non-binary', datetime.date(2020, 10, 7), 'China'),
#  (753, 'Eunice', 'Scain', 'escainkw@altervista.org', 'Genderfluid', datetime.date(2020, 12, 24), 'Philippines'),
#  (755, 'Caro', 'Brach', 'cbrachky@usa.gov', 'Polygender', datetime.date(2020, 9, 19), 'Argentina'),
#  (759, 'Devonna', 'Sayse', 'dsaysel2@wired.com', 'Non-binary', datetime.date(2020, 12, 31), 'Kenya'),
#  (764, 'Javier', 'Putterill', 'jputterilll7@exblog.jp', 'Non-binary', datetime.date(2020, 11, 16), 'China'),
#  (766, 'Lexi', 'Blanc', 'lblancl9@webeden.co.uk', 'Agender', datetime.date(2020, 12, 25), 'Czech Republic'),
#  (770, 'Avie', 'Sudell', 'asudellld@merriam-webster.com', 'Agender', datetime.date(2020, 9, 3), 'Lebanon'),
#  (772, 'Baily', 'Martell', 'bmartelllf@addthis.com', 'Female', datetime.date(2020, 11, 14), 'Russia'),
#  (773, 'Ashli', 'Head', 'aheadlg@sitemeter.com', 'Polygender', datetime.date(2020, 11, 30), 'Nicaragua'),
#  (775, 'Tam', 'Connar', 'tconnarli@jugem.jp', 'Agender', datetime.date(2020, 9, 14), 'Japan'),
#  (776, 'Godiva', 'Scawn', 'gscawnlj@linkedin.com', 'Bigender', datetime.date(2020, 8, 25), 'Suriname'),
#  (778, 'Raviv', 'Cassells', 'rcassellsll@upenn.edu', 'Agender', datetime.date(2020, 9, 26), 'China'),
#  (779, 'Cally', 'Lembke', 'clembkelm@hao123.com', 'Polygender', datetime.date(2020, 10, 28), 'Indonesia'),
#  (781, 'Hubey', 'Pitman', 'hpitmanlo@apple.com', 'Male', datetime.date(2020, 8, 13), 'China'),
#  (782, 'Brockie', 'Sherrocks', None, 'Male', datetime.date(2020, 9, 24), 'Latvia'),
#  (784, 'Barri', 'Wilkennson', None, 'Non-binary', datetime.date(2020, 12, 9), 'China'),
#  (785, 'Evita', 'Pummell', 'epummellls@unblog.fr', 'Genderqueer', datetime.date(2020, 12, 5), 'Cuba'),
#  (787, 'Fee', 'Pennick', 'fpennicklu@last.fm', 'Polygender', datetime.date(2020, 12, 13), 'Indonesia'),
#  (788, 'Ann', 'Keys', 'akeyslv@linkedin.com', 'Genderqueer', datetime.date(2020, 9, 8), 'France'),
#  (790, 'Hyacinthia', 'Poulsen', None, 'Bigender', datetime.date(2020, 9, 16), 'China'),
#  (793, 'Peterus', 'Beazey', None, 'Bigender', datetime.date(2020, 9, 8), 'Ukraine'),
#  (794, 'Kerry', 'Biddiss', 'kbiddissm1@blogs.com', 'Polygender', datetime.date(2020, 8, 23), 'France'),
#  (801, 'Genovera', 'Brymner', None, 'Male', datetime.date(2020, 12, 3), 'Portugal'),
#  (803, 'Collete', 'Simmonett', 'csimmonettma@sphinn.com', 'Genderqueer', datetime.date(2020, 12, 23), 'Nicaragua'),
#  (811, 'Neille', 'Wegener', 'nwegenermi@aol.com', 'Genderqueer', datetime.date(2020, 11, 25), 'Sweden'),
#  (812, 'Jenn', 'Spring', 'jspringmj@usnews.com', 'Male', datetime.date(2020, 10, 18), 'Thailand'),
#  (813, 'Deane', 'MacNamara', 'dmacnamaramk@homestead.com', 'Genderqueer', datetime.date(2020, 11, 16), 'Sweden'),
#  (815, 'Corena', 'Arson', 'carsonmm@phpbb.com', 'Polygender', datetime.date(2020, 8, 10), 'Russia'),
#  (817, 'Barbee', 'Stenyng', None, 'Agender', datetime.date(2020, 8, 25), 'Canada'),
#  (820, 'Thornton', 'Farthin', None, 'Agender', datetime.date(2020, 9, 23), 'China'),
#  (821, 'Nonah', 'Culy', None, 'Genderfluid', datetime.date(2020, 10, 29), 'Philippines'),
#  (822, 'Moyna', 'Castle', 'mcastlemt@alibaba.com', 'Polygender', datetime.date(2020, 12, 23), 'Nigeria'),
#  (825, 'Dillie', 'Rammell', None, 'Male', datetime.date(2020, 10, 21), 'China'),
#  (826, 'Berry', 'Mackro', 'bmackromx@narod.ru', 'Polygender', datetime.date(2020, 9, 10), 'China'),
#  (831, 'Mabelle', 'Driffield', 'mdriffieldn2@msn.com', 'Bigender', datetime.date(2020, 8, 6), 'China'),
#  (832, 'Reed', 'Turneaux', 'rturneauxn3@alibaba.com', 'Agender', datetime.date(2020, 8, 16), 'Russia'),
#  (835, 'Selena', 'Swancock', 'sswancockn6@qq.com', 'Genderfluid', datetime.date(2020, 8, 20), 'Tanzania'),
#  (837, 'Antonetta', 'De Maria', 'ademarian8@miitbeian.gov.cn', 'Polygender', datetime.date(2020, 9, 6), 'Philippines'),
#  (839, 'Finley', 'Behagg', 'fbehaggna@php.net', 'Genderqueer', datetime.date(2020, 9, 29), 'Syria'),
#  (841, 'Josephina', 'Brum', 'jbrumnc@goo.gl', 'Female', datetime.date(2020, 9, 15), 'Poland'),
#  (842, 'Xylia', 'Willows', 'xwillowsnd@vinaora.com', 'Polygender', datetime.date(2020, 10, 28), 'Sweden'),
#  (845, 'Napoleon', 'Keyser', 'nkeyserng@home.pl', 'Male', datetime.date(2020, 9, 24), 'Libya'),
#  (846, 'Dreddy', "O'Riordan", None, 'Non-binary', datetime.date(2020, 12, 1), 'United States'),
#  (848, 'Lauraine', 'Bagg', 'lbaggnj@statcounter.com', 'Bigender', datetime.date(2020, 8, 13), 'Poland'),
#  (853, 'De', 'Guitonneau', 'dguitonneauno@creativecommons.org', 'Genderqueer', datetime.date(2020, 9, 3), 'Indonesia'),
#  (855, 'Zorine', 'Hunnawill', None, 'Female', datetime.date(2020, 11, 14), 'China'),
#  (856, 'Theodor', 'Rigden', 'trigdennr@mozilla.org', 'Genderqueer', datetime.date(2020, 12, 19), 'China'),
#  (857, 'Bastian', 'Dronsfield', None, 'Agender', datetime.date(2020, 8, 18), 'Nigeria'),
#  (858, 'Kennie', 'Trevena', None, 'Non-binary', datetime.date(2020, 9, 14), 'Russia'),
#  (859, 'Fraser', 'Dulanty', None, 'Female', datetime.date(2020, 8, 14), 'Ethiopia'),
#  (861, 'Elly', 'Kubicki', 'ekubickinw@unc.edu', 'Genderfluid', datetime.date(2020, 9, 19), 'China'),
#  (863, 'Eadmund', 'Noble', 'enobleny@infoseek.co.jp', 'Female', datetime.date(2020, 12, 10), 'Venezuela'),
#  (866, 'Gaile', 'Norley', 'gnorleyo1@jigsy.com', 'Non-binary', datetime.date(2020, 8, 7), 'Nigeria'),
#  (867, 'Eleni', 'Corradeschi', 'ecorradeschio2@ow.ly', 'Bigender', datetime.date(2020, 12, 25), 'Russia'),
#  (873, 'Katharine', 'Viel', 'kvielo8@sitemeter.com', 'Male', datetime.date(2020, 10, 9), 'China'),
#  (876, 'Lizbeth', 'Scolland', None, 'Agender', datetime.date(2020, 10, 10), 'Poland'),
#  (878, 'Kippy', 'Radke', None, 'Polygender', datetime.date(2020, 12, 23), 'Brazil'),
#  (879, 'Biron', 'Stroobant', 'bstroobantoe@youtube.com', 'Genderfluid', datetime.date(2020, 12, 22), 'China'),
#  (881, 'Suzy', 'Crowcum', None, 'Polygender', datetime.date(2020, 11, 29), 'Thailand'),
#  (884, 'Kailey', 'Yewdale', 'kyewdaleoj@weebly.com', 'Genderfluid', datetime.date(2020, 10, 10), 'France'),
#  (886, 'Zarla', 'Beamish', 'zbeamishol@mediafire.com', 'Genderfluid', datetime.date(2020, 10, 16), 'Vietnam'),
#  (889, 'Carmelia', 'Lauchlan', None, 'Non-binary', datetime.date(2020, 10, 21), 'Norway'),
#  (891, 'Nap', 'Waterstone', None, 'Bigender', datetime.date(2020, 11, 10), 'Ethiopia'),
#  (892, 'Delila', 'Laughlan', 'dlaughlanor@mapquest.com', 'Genderqueer', datetime.date(2020, 11, 2), 'Indonesia'),
#  (893, 'Amalea', 'Lakeland', None, 'Female', datetime.date(2020, 11, 1), 'Indonesia'),
#  (897, 'Ethelbert', 'Trencher', None, 'Non-binary', datetime.date(2020, 8, 19), 'New Zealand'),
#  (899, 'Eilis', 'Shorie', 'eshorieoy@shareasale.com', 'Male', datetime.date(2020, 9, 20), 'Tanzania'),
#  (902, 'Averell', 'McCuthais', 'amccuthaisp1@so-net.ne.jp', 'Non-binary', datetime.date(2020, 8, 5), 'Mexico'),
#  (904, 'Hurleigh', 'Darville', 'hdarvillep3@about.com', 'Agender', datetime.date(2020, 8, 27), 'Philippines'),
#  (905, 'Cart', 'Bellanger', 'cbellangerp4@telegraph.co.uk', 'Male', datetime.date(2020, 11, 20), 'Costa Rica'),
#  (907, 'Madelon', 'Klassman', 'mklassmanp6@nih.gov', 'Female', datetime.date(2020, 8, 4), 'Mexico'),
#  (910, 'Thurston', 'De Haven', None, 'Bigender', datetime.date(2020, 10, 22), 'United States'),
#  (913, 'Colver', 'Sands-Allan', None, 'Female', datetime.date(2020, 11, 11), 'Czech Republic'),
#  (914, 'Aile', 'Vakhonin', None, 'Genderqueer', datetime.date(2020, 9, 14), 'Venezuela'),
#  (922, 'Elroy', "O'Connolly", 'eoconnollypl@jiathis.com', 'Female', datetime.date(2020, 10, 24), 'France'),
#  (924, 'Adelina', 'Elwill', 'aelwillpn@adobe.com', 'Agender', datetime.date(2020, 12, 15), 'Sweden'),
#  (927, 'Carly', 'Jan', None, 'Male', datetime.date(2020, 9, 10), 'Thailand'),
#  (928, 'Celeste', 'Fawlks', 'cfawlkspr@istockphoto.com', 'Female', datetime.date(2020, 10, 22), 'Russia'),
#  (929, 'Tania', 'Bishell', 'tbishellps@163.com', 'Bigender', datetime.date(2020, 12, 29), 'Indonesia'),
#  (934, 'Sandra', 'Bumpass', None, 'Non-binary', datetime.date(2020, 8, 29), 'China'),
#  (935, 'Zacharie', 'Spinello', 'zspinellopy@umich.edu', 'Non-binary', datetime.date(2020, 9, 26), 'Czech Republic'),
#  (936, 'Cissiee', 'Posthill', None, 'Non-binary', datetime.date(2020, 11, 28), 'France'),
#  (937, 'James', 'Quarrie', 'jquarrieq0@businessweek.com', 'Genderfluid', datetime.date(2020, 8, 7), 'Philippines'),
#  (938, 'Valdemar', 'Rosario', 'vrosarioq1@meetup.com', 'Non-binary', datetime.date(2020, 8, 24), 'China'),
#  (939, 'Aldous', 'Roullier', 'aroullierq2@netlog.com', 'Male', datetime.date(2020, 9, 10), 'Greece'),
#  (941, 'Lynsey', 'Ferris', 'lferrisq4@1688.com', 'Genderfluid', datetime.date(2020, 12, 23), 'Russia'),
#  (945, 'Pauline', 'Wilcock', 'pwilcockq8@a8.net', 'Polygender', datetime.date(2020, 12, 14), 'Costa Rica'),
#  (946, 'Minerva', 'Petrollo', None, 'Bigender', datetime.date(2020, 12, 27), 'East Timor'),
#  (957, 'Deva', 'Lockhart', 'dlockhartqk@un.org', 'Agender', datetime.date(2020, 9, 22), 'Philippines'),
#  (958, 'Bourke', 'Gilford', 'bgilfordql@bbb.org', 'Bigender', datetime.date(2020, 12, 3), 'China'),
#  (963, 'Dot', 'Guillerman', None, 'Female', datetime.date(2020, 8, 31), 'Russia'),
#  (964, 'Honor', 'Knotton', 'hknottonqr@pinterest.com', 'Bigender', datetime.date(2020, 9, 30), 'Indonesia'),
#  (965, 'Bary', 'Sayse', 'bsayseqs@de.vu', 'Non-binary', datetime.date(2020, 10, 16), 'Russia'),
#  (966, 'Halie', 'Bright', 'hbrightqt@businessinsider.com', 'Female', datetime.date(2020, 9, 3), 'China'),
#  (981, 'Birdie', 'Myrtle', None, 'Non-binary', datetime.date(2020, 10, 12), 'China'),
#  (985, 'Adara', 'Stevenson', None, 'Female', datetime.date(2020, 12, 5), 'Croatia'),
#  (987, 'Woodman', 'McGilbon', None, 'Genderfluid', datetime.date(2020, 12, 2), 'Ukraine'),
#  (988, 'Sascha', 'Keating', 'skeatingrf@intel.com', 'Agender', datetime.date(2020, 10, 1), 'Yemen'),
#  (990, 'Piotr', 'Lisle', 'plislerh@wix.com', 'Non-binary', datetime.date(2020, 12, 21), 'Indonesia'),
#  (991, 'Allayne', 'Collier', None, 'Bigender', datetime.date(2020, 10, 10), 'China'),
#  (992, 'Lianna', 'Brooke', 'lbrookerj@nature.com', 'Polygender', datetime.date(2020, 11, 25), 'Brazil'),
#  (993, 'Hobie', 'Handrek', 'hhandrekrk@pinterest.com', 'Genderqueer', datetime.date(2020, 11, 5), 'Czech Republic'),
#  (996, 'Vally', 'Schermick', None, 'Polygender', datetime.date(2020, 9, 1), 'France'),
#  (997, 'Alan', 'Rozea', 'arozearo@trellian.com', 'Male', datetime.date(2020, 12, 3), 'Venezuela'),
#  (999, 'Trixi', 'Spenclay', 'tspenclayrq@thetimes.co.uk', 'Bigender', datetime.date(2020, 9, 6), 'Czech Republic')]

# %%
df = pd.read_sql('SELECT * FROM person', engine)
df
# Out:
#        id first_name  last_name                       email       gender  \
# 0       1      Anton     Robiou       arobiou0@amazon.co.jp      Agender
# 1       2     Oliver    Gwyther           ogwyther1@ihg.com  Genderqueer
# 2       3        Wit      Clash                        None   Non-binary
# 3       4      Henka      Spare         hspare3@dedecms.com   Non-binary
# 4       5    Coretta      Oxton                        None   Non-binary
# ..    ...        ...        ...                         ...          ...
# 995   996      Vally  Schermick                        None   Polygender
# 996   997       Alan      Rozea       arozearo@trellian.com         Male
# 997   998     Krisha      Rappa       krapparp@bandcamp.com   Non-binary
# 998   999      Trixi   Spenclay  tspenclayrq@thetimes.co.uk     Bigender
# 999  1000    Shelden      Elies         seliesrr@google.com  Genderqueer
#
#     date_of_birth country_of_birth
# 0      2020-09-23           Brazil
# 1      2021-01-11         Portugal
# 2      2021-05-14         Thailand
# 3      2020-10-01            Chile
# 4      2021-02-06        Indonesia
# ..            ...              ...
# 995    2020-09-01           France
# 996    2020-12-03        Venezuela
# 997    2021-06-18         Thailand
# 998    2020-09-06   Czech Republic
# 999    2021-03-18      Philippines
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## Joins

# %% [markdown]
# Joins 2 table together using the `ID`. **Join** happens when `Primary key` and `Foreign key` are found on both table.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     person
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 3 rows affected.
# [(3, 'John', 'Matuschek', 'Male', 'john@feedburner.com', datetime.date(1965, 2, 28), 'England', None),
#  (1, 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', 2),
#  (2, 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', 1)]

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     car
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 2 rows affected.
# [(1, 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (2, 'GMC', 'Acadia', Decimal('17662.69'))]

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     person
# JOIN
#     car
# ON
#     person.car_id = car.id
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 2 rows affected.
# [(2, 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', 1, 1, 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (1, 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', 2, 2, 'GMC', 'Acadia', Decimal('17662.69'))]

# %%
# %%sql
#
# SELECT
#     person.first_name, car.make, car.model, car.price
# FROM
#     person
# JOIN
#     car
# ON
#     person.car_id = car.id;
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 2 rows affected.
# [('Omar', 'Land Rover', 'Sterling', Decimal('87665.38')),
#  ('Fernanda', 'GMC', 'Acadia', Decimal('17662.69'))]

# %% [markdown]
# ## Left joins
#
# ABLE to let people with no id to return result. For normal joins, table with no ID is discarded from showing result

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     person
# LEFT JOIN
#     car
# ON
#     person.car_id = car.id;
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 4 rows affected.
# [(2, 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', 1, 1, 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (1, 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', 2, 2, 'GMC', 'Acadia', Decimal('17662.69')),
#  (9000, 'John', 'Smith', 'Genderqueer', 'ogwyther1@ihg.com', datetime.date(2021, 1, 11), 'Portugal', None, None, None, None, None),
#  (3, 'John', 'Matuschek', 'Male', 'john@feedburner.com', datetime.date(1965, 2, 28), 'England', None, None, None, None, None)]

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     person
# WHERE
#      car_id IS NULL
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# [(3, 'John', 'Matuschek', 'Male', 'john@feedburner.com', datetime.date(1965, 2, 28), 'England', None)]

# %%
# %%sql
#
# insert into car (id, make, model, price) values (13, 'Mazda', 'RX-8', '51272.48')
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-63-0acad9ca8464> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "\ninsert into car (id, make, model, price) values (13, 'Mazda', 'RX-8', '51272.48')\n")
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     car
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 5 rows affected.
# [(1, 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (2, 'GMC', 'Acadia', Decimal('17662.69')),
#  (13, 'Mazda', 'RX-8', Decimal('51272.48')),
#  (3, 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (4, 'GMC', 'Acadia', Decimal('17662.69'))]

# %%
# %%sql
# insert into person (id, first_name, last_name, email, gender, date_of_birth, country_of_birth) values (9000,'John', 'Smith', 'ogwyther1@ihg.com', 'Genderqueer', '2021-01-11', 'Portugal');
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-57-06b323ff6b88> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "insert into person (id, first_name, last_name, email, gender, date_of_birth, country_of_birth) values (9000,'John', 'Smith', 'ogwyther1@ihg.com', 'Genderqueer', '2021-01-11', 'Portugal');\n")
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
#
# UPDATE person SET car_id = 2 WHERE ID = 1;
# UPDATE person SET car_id = 1 WHERE ID = 2;
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-59-4df316630430> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nUPDATE person SET car_id = 2 WHERE ID = 1;\nUPDATE person SET car_id = 1 WHERE ID = 2;\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     car
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 3 rows affected.
# [(1, 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (2, 'GMC', 'Acadia', Decimal('17662.69')),
#  (13, 'Mazda', 'RX-8', Decimal('51272.48'))]

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     person
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 3 rows affected.
# [(3, 'John', 'Matuschek', 'Male', 'john@feedburner.com', datetime.date(1965, 2, 28), 'England', None),
#  (1, 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', 2),
#  (2, 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', 1)]

# %%
# %%sql
#
# UPDATE person SET car_id = 13 WHERE id =9000
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-68-be93c5c57b27> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nUPDATE person SET car_id = 13 WHERE id =9000;\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# To delete car ID from car table, you must first delete rows on person table that contain the car ID first, so in this case, I can remove the id 9000 rows or just remove the car_id 13 from the row id 9000.

# %%
# %%sql
#
# DELETE FROM person
# WHERE
#     id = 9000
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-70-19e847526590> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nDELETE FROM person\nWHERE\n    id = 9000\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# ### Deleting foreign key

# %%
# %%sql
# DELETE FROM car WHERE id =13
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-72-a62745b8428d> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'DELETE FROM car WHERE id =13\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# SELECT * FROM car
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 2 rows affected.
# [(1, 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (2, 'GMC', 'Acadia', Decimal('17662.69'))]

# %% [markdown]
# Now, the car id 13 is removed from the table car.

# %%
jovian.commit(project = 'intro-postgresql')
# Out:
# [jovian] Updating notebook "sunskung/intro-postgresql" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/sunskung/intro-postgresql
# 'https://jovian.ai/sunskung/intro-postgresql'

# %% [markdown]
# # Sequence

# %%
# %%sql
# SELECT * FROM person_id_seq
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# [(3, 30, True)]

# %%
# %%sql
# SELECT nextval('person_id_seq'::regclass)
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# [(4,)]

# %% [markdown]
# What we did up there is that, if we add one more rows to the table; the ID will move to `5` instead of 4. Let's try that below.

# %%
# %%sql
# SELECT * FROM person
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 3 rows affected.
# [(3, 'John', 'Matuschek', 'Male', 'john@feedburner.com', datetime.date(1965, 2, 28), 'England', None),
#  (1, 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', 2),
#  (2, 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', 1)]

# %%
# %%sql
# insert into person (first_name, last_name, gender, email, date_of_birth, country_of_birth) values ('John', 'Matuschek', 'Male', 'john@feedburner.com', '1965-02-28', 'England');
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-11-22eedaa014ab> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "insert into person (first_name, last_name, gender, email, date_of_birth, country_of_birth) values ('John', 'Matuschek', 'Male', 'john@feedburner.com', '1965-02-28', 'England');\n")
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# SELECT * FROM person
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 4 rows affected.
# [(3, 'John', 'Matuschek', 'Male', 'john@feedburner.com', datetime.date(1965, 2, 28), 'England', None),
#  (1, 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', 2),
#  (2, 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', 1),
#  (5, 'John', 'Matuschek', 'Male', 'john@feedburner.com', datetime.date(1965, 2, 28), 'England', None)]

# %% [markdown]
# As you can see, it returns 5 on ID column which is our primary key.

# %% [markdown]
# To restart the sequence, do the following:. The sequence will return to the assigned value.

# %%
# %%sql
# ALTER SEQUENCE person_id_seq RESTART WITH 10;
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# Done.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-14-83446d06bc8c> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'ALTER SEQUENCE person_id_seq RESTART WITH 10;\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# SELECT * FROM person_id_seq
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# [(10, 0, False)]

# %% [markdown]
# ## Extension

# %%
# %%sql
# SELECT * FROM pg_available_extensions
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 86 rows affected.
# [('adminpack', '2.1', None, 'administrative functions for PostgreSQL'),
#  ('amcheck', '1.2', None, 'functions for verifying relation integrity'),
#  ('autoinc', '1.0', None, 'functions for autoincrementing fields'),
#  ('bloom', '1.0', None, 'bloom access method - signature file based index'),
#  ('bool_plperl', '1.0', None, 'transform between bool and plperl'),
#  ('bool_plperlu', '1.0', None, 'transform between bool and plperlu'),
#  ('btree_gin', '1.3', None, 'support for indexing common datatypes in GIN'),
#  ('btree_gist', '1.5', None, 'support for indexing common datatypes in GiST'),
#  ('citext', '1.6', None, 'data type for case-insensitive character strings'),
#  ('cube', '1.4', None, 'data type for multidimensional cubes'),
#  ('dblink', '1.2', None, 'connect to other PostgreSQL databases from within a database'),
#  ('dict_int', '1.0', None, 'text search dictionary template for integers'),
#  ('dict_xsyn', '1.0', None, 'text search dictionary template for extended synonym processing'),
#  ('dummy_index_am', '1.0', None, 'dummy_index_am - index access method template'),
#  ('earthdistance', '1.1', None, 'calculate great-circle distances on the surface of the Earth'),
#  ('file_fdw', '1.0', None, 'foreign-data wrapper for flat file access'),
#  ('fuzzystrmatch', '1.1', None, 'determine similarities and distance between strings'),
#  ('hstore', '1.7', None, 'data type for storing sets of (key, value) pairs'),
#  ('hstore_plperl', '1.0', None, 'transform between hstore and plperl'),
#  ('hstore_plperlu', '1.0', None, 'transform between hstore and plperlu'),
#  ('hstore_plpython2u', '1.0', None, 'transform between hstore and plpython2u'),
#  ('hstore_plpython3u', '1.0', None, 'transform between hstore and plpython3u'),
#  ('hstore_plpythonu', '1.0', None, 'transform between hstore and plpythonu'),
#  ('insert_username', '1.0', None, 'functions for tracking who changed a table'),
#  ('intagg', '1.1', None, 'integer aggregator and enumerator (obsolete)'),
#  ('intarray', '1.3', None, 'functions, operators, and index support for 1-D arrays of integers'),
#  ('isn', '1.2', None, 'data types for international product numbering standards'),
#  ('jsonb_plperl', '1.0', None, 'transform between jsonb and plperl'),
#  ('jsonb_plperlu', '1.0', None, 'transform between jsonb and plperlu'),
#  ('jsonb_plpython2u', '1.0', None, 'transform between jsonb and plpython2u'),
#  ('jsonb_plpython3u', '1.0', None, 'transform between jsonb and plpython3u'),
#  ('jsonb_plpythonu', '1.0', None, 'transform between jsonb and plpythonu'),
#  ('lo', '1.1', None, 'Large Object maintenance'),
#  ('ltree', '1.2', None, 'data type for hierarchical tree-like structures'),
#  ('ltree_plpython2u', '1.0', None, 'transform between ltree and plpython2u'),
#  ('ltree_plpython3u', '1.0', None, 'transform between ltree and plpython3u'),
#  ('ltree_plpythonu', '1.0', None, 'transform between ltree and plpythonu'),
#  ('moddatetime', '1.0', None, 'functions for tracking last modification time'),
#  ('pageinspect', '1.8', None, 'inspect the contents of database pages at a low level'),
#  ('pgcrypto', '1.3', None, 'cryptographic functions'),
#  ('pgrowlocks', '1.2', None, 'show row-level locking information'),
#  ('pgstattuple', '1.5', None, 'show tuple-level statistics'),
#  ('pg_buffercache', '1.3', None, 'examine the shared buffer cache'),
#  ('pg_freespacemap', '1.2', None, 'examine the free space map (FSM)'),
#  ('pg_prewarm', '1.2', None, 'prewarm relation data'),
#  ('pg_stat_statements', '1.8', None, 'track planning and execution statistics of all SQL statements executed'),
#  ('pg_trgm', '1.5', None, 'text similarity measurement and index searching based on trigrams'),
#  ('pg_visibility', '1.2', None, 'examine the visibility map (VM) and page-level visibility info'),
#  ('pldbgapi', '1.1', None, 'server-side support for debugging PL/pgSQL functions'),
#  ('plperl', '1.0', None, 'PL/Perl procedural language'),
#  ('plperlu', '1.0', None, 'PL/PerlU untrusted procedural language'),
#  ('plpgsql', '1.0', '1.0', 'PL/pgSQL procedural language'),
#  ('plpython2u', '1.0', None, 'PL/Python2U untrusted procedural language'),
#  ('plpython3u', '1.0', None, 'PL/Python3U untrusted procedural language'),
#  ('plpythonu', '1.0', None, 'PL/PythonU untrusted procedural language'),
#  ('pltcl', '1.0', None, 'PL/Tcl procedural language'),
#  ('pltclu', '1.0', None, 'PL/TclU untrusted procedural language'),
#  ('postgres_fdw', '1.0', None, 'foreign-data wrapper for remote PostgreSQL servers'),
#  ('refint', '1.0', None, 'functions for implementing referential integrity (obsolete)'),
#  ('seg', '1.3', None, 'data type for representing line segments or floating-point intervals'),
#  ('sslinfo', '1.2', None, 'information about SSL certificates'),
#  ('system_stats', '1.0', None, 'EnterpriseDB system statistics for PostgreSQL'),
#  ('tablefunc', '1.0', None, 'functions that manipulate whole tables, including crosstab'),
#  ('tcn', '1.0', None, 'Triggered change notifications'),
#  ('test_bloomfilter', '1.0', None, 'Test code for Bloom filter library'),
#  ('test_ext1', '1.0', None, 'Test extension 1'),
#  ('test_ext2', '1.0', None, 'Test extension 2'),
#  ('test_ext3', '1.0', None, 'Test extension 3'),
#  ('test_ext4', '1.0', None, 'Test extension 4'),
#  ('test_ext5', '1.0', None, 'Test extension 5'),
#  ('test_ext6', '1.0', None, 'test_ext6'),
#  ('test_ext7', '1.0', None, 'Test extension 7'),
#  ('test_ext8', '1.0', None, 'Test extension 8'),
#  ('test_ext_cyclic1', '1.0', None, 'Test extension cyclic 1'),
#  ('test_ext_cyclic2', '1.0', None, 'Test extension cyclic 2'),
#  ('test_ext_evttrig', '1.0', None, 'Test extension - event trigger'),
#  ('test_ginpostinglist', '1.0', None, 'Test code for ginpostinglist.c'),
#  ('test_integerset', '1.0', None, 'Test code for integerset'),
#  ('test_pg_dump', '1.0', None, 'Test pg_dump with an extension'),
#  ('test_predtest', '1.0', None, 'Test code for optimizer/util/predtest.c'),
#  ('test_rbtree', '1.0', None, 'Test code for red-black tree library'),
#  ('tsm_system_rows', '1.0', None, 'TABLESAMPLE method which accepts number of rows as a limit'),
#  ('tsm_system_time', '1.0', None, 'TABLESAMPLE method which accepts time in milliseconds as a limit'),
#  ('unaccent', '1.1', None, 'text search dictionary that removes accents'),
#  ('uuid-ossp', '1.1', None, 'generate universally unique identifiers (UUIDs)'),
#  ('xml2', '1.1', None, 'XPath querying and XSLT')]

# %% [markdown]
# ## Installing UUID Extension

# %%
# %%sql
# CREATE EXTENSION IF NOT EXISTS "uuid-ossp"
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# Done.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-25-93e19082731f> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE EXTENSION IF NOT EXISTS "uuid-ossp" \n;\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# Generate random ID to use as ID primary key. It is unique, and it makes it harder for hacker to manipulate or change our database.

# %%
# %%sql
# SELECT uuid_generate_v4();
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# [(UUID('33044f6f-fc16-44d4-8523-04b5a3f483d4'),)]

# %%
# %%sql
# DROP TABLE person
# DROP TABLE car
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# (psycopg2.errors.SyntaxError) syntax error at or near "DROP"
# LINE 1: DROP TABLE person DROP TABLE car
#                           ^
#
# [SQL: DROP TABLE person DROP TABLE car]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
#
# DROP TABLE car
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# Done.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-29-bcf1cb633599> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nDROP TABLE car\n')
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# SELECT * FROM person
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 3 rows affected.
# [(UUID('cf4055c4-bed3-4558-87f5-a3f5b42b0003'), 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', None),
#  (UUID('8ead019b-f873-4688-a2d2-5fe35cbd475c'), 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', None),
#  (UUID('e357dcc0-8088-4f64-a168-b9608c6bc0fb'), 'Adriana', 'Matuschek', 'Female', 'amatuschek2@feedburner.com', datetime.date(1965, 2, 28), 'Cameroon', None)]

# %%
# %%sql
# SELECT * FROM car
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 2 rows affected.
# [(UUID('f262cf81-6b5f-4440-9de6-1d0410b15646'), 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (UUID('f00fd8c5-97ee-43fa-9497-b82b4038e635'), 'GMC', 'Acadia', Decimal('17662.69'))]

# %%
# %%sql
# UPDATE person SET car_uid = 'f262cf81-6b5f-4440-9de6-1d0410b15646'
# WHERE person_uid = 'e357dcc0-8088-4f64-a168-b9608c6bc0fb'
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-34-017a134fe6da> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "UPDATE person SET car_uid = 'f262cf81-6b5f-4440-9de6-1d0410b15646'\nWHERE person_uid = 'e357dcc0-8088-4f64-a168-b9608c6bc0fb'\n")
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# UPDATE person SET car_uid = 'f00fd8c5-97ee-43fa-9497-b82b4038e635'
# WHERE person_uid = '8ead019b-f873-4688-a2d2-5fe35cbd475c'
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-37-93a80f115d79> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "UPDATE person SET car_uid = 'f00fd8c5-97ee-43fa-9497-b82b4038e635'\nWHERE person_uid = '8ead019b-f873-4688-a2d2-5fe35cbd475c'\n")
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     369             if result and config.feedback:
#     370                 print(interpret_rowcount(result.rowcount))
# --> 371         resultset = ResultSet(result, statement, config)
#     372         if config.autopandas:
#     373             return resultset.DataFrame()
#
# ~\anaconda3\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# SELECT * FROM person
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 3 rows affected.
# [(UUID('cf4055c4-bed3-4558-87f5-a3f5b42b0003'), 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', None),
#  (UUID('e357dcc0-8088-4f64-a168-b9608c6bc0fb'), 'Adriana', 'Matuschek', 'Female', 'amatuschek2@feedburner.com', datetime.date(1965, 2, 28), 'Cameroon', UUID('f262cf81-6b5f-4440-9de6-1d0410b15646')),
#  (UUID('8ead019b-f873-4688-a2d2-5fe35cbd475c'), 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', UUID('f00fd8c5-97ee-43fa-9497-b82b4038e635'))]

# %%
# %%sql
# SELECT * FROM car
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 2 rows affected.
# [(UUID('f262cf81-6b5f-4440-9de6-1d0410b15646'), 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (UUID('f00fd8c5-97ee-43fa-9497-b82b4038e635'), 'GMC', 'Acadia', Decimal('17662.69'))]

# %% [markdown]
# Let's join both table together.

# %%
# %%sql
# SELECT * FROM person
# JOIN car ON person.car_uid = car.car_uid
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 2 rows affected.
# [(UUID('e357dcc0-8088-4f64-a168-b9608c6bc0fb'), 'Adriana', 'Matuschek', 'Female', 'amatuschek2@feedburner.com', datetime.date(1965, 2, 28), 'Cameroon', UUID('f262cf81-6b5f-4440-9de6-1d0410b15646'), UUID('f262cf81-6b5f-4440-9de6-1d0410b15646'), 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (UUID('8ead019b-f873-4688-a2d2-5fe35cbd475c'), 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', UUID('f00fd8c5-97ee-43fa-9497-b82b4038e635'), UUID('f00fd8c5-97ee-43fa-9497-b82b4038e635'), 'GMC', 'Acadia', Decimal('17662.69'))]

# %% [markdown]
# Since the foreign and the primary key are the same, we use other function to do join.

# %%
# %%sql
# SELECT * FROM person
# JOIN car USING (car_uid)
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 2 rows affected.
# [(UUID('f262cf81-6b5f-4440-9de6-1d0410b15646'), UUID('e357dcc0-8088-4f64-a168-b9608c6bc0fb'), 'Adriana', 'Matuschek', 'Female', 'amatuschek2@feedburner.com', datetime.date(1965, 2, 28), 'Cameroon', 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (UUID('f00fd8c5-97ee-43fa-9497-b82b4038e635'), UUID('8ead019b-f873-4688-a2d2-5fe35cbd475c'), 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', 'GMC', 'Acadia', Decimal('17662.69'))]

# %%
# %%sql
# SELECT * FROM person
# LEFT JOIN car USING (car_uid)
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 3 rows affected.
# [(UUID('f262cf81-6b5f-4440-9de6-1d0410b15646'), UUID('e357dcc0-8088-4f64-a168-b9608c6bc0fb'), 'Adriana', 'Matuschek', 'Female', 'amatuschek2@feedburner.com', datetime.date(1965, 2, 28), 'Cameroon', 'Land Rover', 'Sterling', Decimal('87665.38')),
#  (UUID('f00fd8c5-97ee-43fa-9497-b82b4038e635'), UUID('8ead019b-f873-4688-a2d2-5fe35cbd475c'), 'Omar', 'Colmore', 'Male', None, datetime.date(1921, 4, 3), 'Finland', 'GMC', 'Acadia', Decimal('17662.69')),
#  (None, UUID('cf4055c4-bed3-4558-87f5-a3f5b42b0003'), 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', None, None, None)]

# %%
# %%sql
# SELECT * FROM person
# LEFT JOIN car USING (car_uid)
# WHERE car.* IS NULL
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# 1 rows affected.
# [(None, UUID('cf4055c4-bed3-4558-87f5-a3f5b42b0003'), 'Fernanda', 'Beardon', 'Female', 'fernandab@is.gd', datetime.date(1953, 10, 28), 'Comoros', None, None, None)]

# %% [markdown]
# ## Export to CSV

# %%
# %%sql
# \copy (SELECT * FROM person LEFT JOIN car USING (car_uid))
# TO 'C:/Users/Phurin Chawjarusopas/Desktop/Intro psql file/sql-postgres-course-main/intro to psql workbook.csv' DELIMITER ',' CSV HEADER
# Out:
#  * postgresql://postgres:***@localhost/sunsql
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-57-22cc85050084> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "\\copy (SELECT * FROM person LEFT JOIN car USING (car_uid)) \nTO 'C:/Users/Phurin Chawjarusopas/Desktop/Intro psql file/sql-postgres-course-main/intro to psql workbook.csv' DELIMITER ',' CSV HEADER\n")
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#     215
#     216         try:
# --> 217             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     218
#     219             if (
#
# ~\anaconda3\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     357             if first_word.startswith("\\") and "postgres" in str(conn.dialect):
#     358                 if not PGSpecial:
# --> 359                     raise ImportError("pgspecial not installed")
#     360                 pgspecial = PGSpecial()
#     361                 _, cur, headers, _ = pgspecial.execute(
#
# ImportError: pgspecial not installed

# %%
jovian.commit(project = 'intro-postgresql')
# Out:
# [jovian] Updating notebook "sunskung/intro-postgresql" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/sunskung/intro-postgresql
# 'https://jovian.ai/sunskung/intro-postgresql'
